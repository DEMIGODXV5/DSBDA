# %%
import pandas as pd
import numpy as np
import sklearn
from sklearn import datasets

# %%
df=pd.read_csv("/home/hardwarelab00/Downloads/Iris.csv")

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.tail()
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 145  Iris-virginica
# 146  Iris-virginica
# 147  Iris-virginica
# 148  Iris-virginica
# 149  Iris-virginica

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.shape()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.shape
# Out:
# (150, 6)

# %%
df.mean(numeric_only=True)
# Out:
# Id               75.500000
# SepalLengthCm     5.843333
# SepalWidthCm      3.054000
# PetalLengthCm     3.758667
# PetalWidthCm      1.198667
# dtype: float64

# %%
df.median(numeric_only=True)
# Out:
# Id               75.50
# SepalLengthCm     5.80
# SepalWidthCm      3.00
# PetalLengthCm     4.35
# PetalWidthCm      1.30
# dtype: float64

# %%
data.species.mode()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data.species.mode()
#
# NameError: name 'data' is not defined

# %%
df.Species.mode()
# Out:
# 0        Iris-setosa
# 1    Iris-versicolor
# 2     Iris-virginica
# Name: Species, dtype: object

# %%
df.groupby(["Species"]).count()
# Out:
#                  Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# Species
# Iris-setosa      50             50            50             50            50
# Iris-versicolor  50             50            50             50            50
# Iris-virginica   50             50            50             50            50

# %%
df.SepalLengthCm.std()
# Out:
# 0.828066127977863

# %%
df.SepalWidthCm.std()
# Out:
# 0.4335943113621737

# %%
df.PetalLengthCm.std()
# Out:
# 1.7644204199522626

# %%
df.PetalLengthCm.std()
# Out:
# 1.7644204199522626

# %%
df.PetalWidthCm.std()
# Out:
# 0.7631607417008411

# %%
df.rename(columns={'SepalLengthCm':'NEWSepalLengthCm','SepalWidthCm':'NEWSepalWidthCm','PetalLengthCm':'NEWPetalLengthCm','PetalWidthCm':'NEWPetalWidthCm'},inplace=True)

# %%
print("Column renaming... Table after Renaming columns")
df.head()
# Out:
# Column renaming... Table after Renaming columns
#    Id  NEWSepalLengthCm  NEWSepalWidthCm  NEWPetalLengthCm  NEWPetalWidthCm  \
# 0   1               5.1              3.5               1.4              0.2
# 1   2               4.9              3.0               1.4              0.2
# 2   3               4.7              3.2               1.3              0.2
# 3   4               4.6              3.1               1.5              0.2
# 4   5               5.0              3.6               1.4              0.2
#
#        Species
# 0  Iris-setosa
# 1  Iris-setosa
# 2  Iris-setosa
# 3  Iris-setosa
# 4  Iris-setosa
